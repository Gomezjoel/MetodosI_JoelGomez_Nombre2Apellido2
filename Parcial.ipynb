# %%
import numpy as np
import matplotlib.pyplot as plt
from tabulate import tabulate
def f(x):
    return (3*x**5) + (5*x**4) - (x**3)
def df(x):
    return (15*x**4) + (20*x**3) - (3*x**2)
valoresx = np.linspace(-0.10,0.20,1000)
y = f(valoresx)
plt.axhline(0)
plt.plot(valoresx,y)
delta = 1e-10
guess = 0.02
guess1 = 0.17
while abs(f(guess)) > delta:
    guess = guess - f(guess)/df(guess)
while abs(f(guess1)) > delta:
    guess1 = guess1 - f(guess1)/df(guess1)
